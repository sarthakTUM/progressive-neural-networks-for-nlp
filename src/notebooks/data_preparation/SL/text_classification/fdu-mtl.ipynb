# %%
import pandas as pd
import numpy as np
import sys
import os
import random, string

# %%
sys.path.append('../../../../')

# %%
def SL(in_file, out_folder):
    with open(in_file) as f:
        # get setence as tokenized words
        sentences = []
        labels = []
        with open(in_file, 'r') as f:
            lines = f.readlines()
            for line in lines:
                line = line.rstrip()
                # print(line)
                tag = line.split('\t', 1)[0]
                sent = line.split('\t', 1)[1]
                sentences.append(sent)
                labels.append(tag)
        sentences_file = os.path.join(out_folder, 'sentences.txt')
        labels_file = os.path.join(out_folder, 'labels.txt')
        id_file = os.path.join(out_folder, 'ID.txt')
        with open(sentences_file, 'a') as s_f, open(labels_file, 'a') as l_f, open(id_file, 'a') as i_f:
            for sentence, label in zip(sentences, labels):
                id_str = ''.join(random.choices(string.ascii_letters + string.digits, k=16))
                s_f.write(sentence+'\n')
                l_f.write(label+'\n')
                i_f.write(id_str+'\n')

# %%
op_data = '../../../../../src/tc/data/baby'
if not os.path.exists(op_data):
    os.makedirs(op_data)
# TRAIN
in_file = '../../../../../resources/data/TC/fdu-mtl/baby.pp.train'
out_folder = os.path.join(op_data, 'train')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# VAL
in_file = '../../../../../resources/data/TC/fdu-mtl/baby.pp.val'
out_folder = os.path.join(op_data, 'val')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# TEST
in_file = '../../../../../resources/data/TC/fdu-mtl/baby.task.test'
out_folder = os.path.join(op_data, 'test')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# %%
op_data = '../../../../../src/tc/data/apparel'
if not os.path.exists(op_data):
    os.makedirs(op_data)
# TRAIN
in_file = '../../../../../resources/data/TC/fdu-mtl/apparel.pp.train'
out_folder = os.path.join(op_data, 'train')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# VAL
in_file = '../../../../../resources/data/TC/fdu-mtl/apparel.pp.val'
out_folder = os.path.join(op_data, 'val')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# TEST
in_file = '../../../../../resources/data/TC/fdu-mtl/baby.task.test'
out_folder = os.path.join(op_data, 'test')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# %%
op_data = '../../../../../src/tc/data/books'
if not os.path.exists(op_data):
    os.makedirs(op_data)
# TRAIN
in_file = '../../../../../resources/data/TC/fdu-mtl/books.pp.train'
out_folder = os.path.join(op_data, 'train')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# VAL
in_file = '../../../../../resources/data/TC/fdu-mtl/books.pp.val'
out_folder = os.path.join(op_data, 'val')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# TEST
in_file = '../../../../../resources/data/TC/fdu-mtl/books.task.test'
out_folder = os.path.join(op_data, 'test')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# %%
op_data = '../../../../../src/tc/data/electronics'
if not os.path.exists(op_data):
    os.makedirs(op_data)
# TRAIN
in_file = '../../../../../resources/data/TC/fdu-mtl/electronics.pp.train'
out_folder = os.path.join(op_data, 'train')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# VAL
in_file = '../../../../../resources/data/TC/fdu-mtl/electronics.pp.val'
out_folder = os.path.join(op_data, 'val')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# TEST
in_file = '../../../../../resources/data/TC/fdu-mtl/electronics.task.test'
out_folder = os.path.join(op_data, 'test')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# %%
op_data = '../../../../../src/tc/data/imdb'
if not os.path.exists(op_data):
    os.makedirs(op_data)
# TRAIN
in_file = '../../../../../resources/data/TC/fdu-mtl/imdb.pp.train'
out_folder = os.path.join(op_data, 'train')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# VAL
in_file = '../../../../../resources/data/TC/fdu-mtl/imdb.pp.val'
out_folder = os.path.join(op_data, 'val')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# TEST
in_file = '../../../../../resources/data/TC/fdu-mtl/imdb.task.test'
out_folder = os.path.join(op_data, 'test')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# %%
op_data = '../../../../../src/tc/data/kitchen_housewares'
if not os.path.exists(op_data):
    os.makedirs(op_data)
# TRAIN
in_file = '../../../../../resources/data/TC/fdu-mtl/kitchen_housewares.pp.train'
out_folder = os.path.join(op_data, 'train')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# VAL
in_file = '../../../../../resources/data/TC/fdu-mtl/kitchen_housewares.pp.val'
out_folder = os.path.join(op_data, 'val')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# TEST
in_file = '../../../../../resources/data/TC/fdu-mtl/kitchen_housewares.task.test'
out_folder = os.path.join(op_data, 'test')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# %%
op_data = '../../../../../src/tc/data/health_personal_care'
if not os.path.exists(op_data):
    os.makedirs(op_data)
# TRAIN
in_file = '../../../../../resources/data/TC/fdu-mtl/health_personal_care.pp.train'
out_folder = os.path.join(op_data, 'train')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# VAL
in_file = '../../../../../resources/data/TC/fdu-mtl/health_personal_care.pp.val'
out_folder = os.path.join(op_data, 'val')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)

# TEST
in_file = '../../../../../resources/data/TC/fdu-mtl/health_personal_care.task.test'
out_folder = os.path.join(op_data, 'test')
if not os.path.exists(out_folder):
    os.makedirs(out_folder)
SL(in_file, out_folder)
